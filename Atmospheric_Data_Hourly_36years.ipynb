# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("C://atmos/years.csv")[0:315360]
length=data.size
dp=data['Year1'].values
print(dp[0:8760])
dp1=dp[0:8760]
dp2=dp[8760:17520]
dp3=dp[17520:26280]
dp4=dp[26280:35040]
dp5=dp[35040:43800]
dp6=dp[43800:52560]
dp7=dp[52560:61320]
dp8=dp[61320:70080]
dp9=dp[70080:78840]
dp10=dp[78840:87600]
dp11=dp[87600:96360]
dp12=dp[96360:105120]
dp13=dp[105120:113880]
dp14=dp[113880:122640]
dp15=dp[122640:131400]
dp16=dp[131400:140160]
dp17=dp[140160:148920]
dp18=dp[148920:157680]
dp19=dp[157680:166440]
dp20=dp[166440:175200]
dp21=dp[175200:183960]
dp22=dp[183960:192720]
dp23=dp[192720:201480]
dp24=dp[201480:210240]
dp25=dp[210240:219000]
dp26=dp[219000:227760]
dp27=dp[227760:236520]
dp28=dp[236520:245280]
dp29=dp[245280:254040]
dp30=dp[254040:262800]
dp31=dp[262800:271560]
dp32=dp[271560:280320]
dp33=dp[280320:289080]
dp34=dp[289080:297840]
dp35=dp[297840:306600]
dp36=dp[306600:315360]

print("mean is "+str(dp1.mean()))
print(dp1.size,dp2.size,dp3.size,dp4.size,dp5.size,dp6.size,dp7.size,dp8.size,dp9.size)
j=0
for i in range(36):
    j+=8760
    l=j+8760
    #print( dp[j:l])
    
    print(j,l)
    
print(dp1.shape)
print(dp2.shape)
      
final = {'Y1':dp1, 'Y2':dp2 ,'Y3':dp3,'Y4':dp4,'Y5':dp5,'Y6':dp6,'Y7':dp7,'Y8':dp8,'Y9':dp9,'Y10':dp10,'Y11':dp11,'Y12':dp13,'Y13':dp13,
        'Y14':dp14,'Y15':dp15,'Y16':dp16,'Y17':dp17,'Y18':dp18,'Y19':dp19,'Y20':dp20,'Y21':dp21,'Y22':dp22,'Y23':dp23,'Y24':dp24,'Y25':dp25,'Y26':dp26,'Y27':dp27,'Y28':dp28,'Y29':dp29,'Y30':dp30,
        'Y31':dp31,'Y32':dp32,'Y33':dp33,'Y34':dp34,'Y35':dp35,'Y36':dp36}
print(final)

final_data=pd.DataFrame.from_dict(final)
print(final_data.transpose())
export_data=final_data.to_csv(r'C://atmos/new_years.csv',index=None,header=True)
# Out:
# [296.755188  293.7626648 290.9171448 ... 328.8797302 324.8607483
#  321.2593079]
# mean is 372.31638416517126
# 8760 8760 8760 8760 8760 8760 8760 8760 8760
# 8760 17520
# 17520 26280
# 26280 35040
# 35040 43800
# 43800 52560
# 52560 61320
# 61320 70080
# 70080 78840
# 78840 87600
# 87600 96360
# 96360 105120
# 105120 113880
# 113880 122640
# 122640 131400
# 131400 140160
# 140160 148920
# 148920 157680
# 157680 166440
# 166440 175200
# 175200 183960
# 183960 192720
# 192720 201480
# 201480 210240
# 210240 219000
# 219000 227760
# 227760 236520
# 236520 245280
# 245280 254040
# 254040 262800
# 262800 271560
# 271560 280320
# 280320 289080
# 289080 297840
# 297840 306600
# 306600 315360
# 315360 324120
# (8760,)
# (8760,)
# {'Y1': array([296.755188 , 293.7626648, 290.9171448, ..., 328.8797302,
#        324.8607483, 321.2593079]), 'Y2': array([318.4733276, 316.2879944, 314.3492737, ..., 315.1915894,
# ...
